# %% [markdown]
# # Análise dos sinais do cenário 1
# Este notebook irá carregar o arquivo `cenario_1_resultados.csv` e plotar os principais sinais do sistema, incluindo os setpoints de referência.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Carregar o arquivo CSV

file_path = 'cenario_1/cenario_1_resultados.csv'

df = pd.read_csv(file_path)
df.head()
# Out:
#    tempo        hA        hB        hC     CC        hD     CD        hE  \
# 0    0.0  1.500000  1.500000  1.500000  180.0  1.500000  180.0  1.500000
# 1    0.5  1.499999  1.499999  1.500000  180.0  1.500000  180.0  1.500000
# 2    1.0  1.499999  1.499999  1.500001  180.0  1.500001  180.0  1.500001
# 3    1.5  1.499998  1.499998  1.500001  180.0  1.500001  180.0  1.500001
# 4    2.0  1.499998  1.499998  1.500001  180.0  1.500001  180.0  1.500001
#
#       CE     uA  ...  uD3     uE1     uE2  uE3  hC_ref  CC_ref  hD_ref  \
# 0  180.0  0.000  ...  0.0  0.0000  0.0000  0.0     1.5   180.0     1.5
# 1  180.0  0.306  ...  0.5  0.6125  0.6125  0.5     1.5   180.0     1.5
# 2  180.0  0.306  ...  0.5  0.6125  0.6125  0.5     1.5   180.0     1.5
# 3  180.0  0.306  ...  0.5  0.6125  0.6125  0.5     1.5   180.0     1.5
# 4  180.0  0.306  ...  0.5  0.6125  0.6125  0.5     1.5   180.0     1.5
#
#    CD_ref  hE_ref  CE_ref
# 0   180.0     1.5   180.0
# 1   180.0     1.5   180.0
# ...

# %% [markdown]
# ## Gráficos dos níveis dos tanques (com referência)

# %%
plt.figure(figsize=(12,6))
plt.plot(df['tempo'], df['hA'], label='hA')
plt.plot(df['tempo'], df['hB'], label='hB')
plt.plot(df['tempo'], df['hC'], label='hC')
plt.plot(df['tempo'], df['hD'], label='hD')
plt.plot(df['tempo'], df['hE'], label='hE')
plt.plot(df['tempo'], df['hC_ref'], '--', label='hC_ref')
plt.plot(df['tempo'], df['hD_ref'], '--', label='hD_ref')
plt.plot(df['tempo'], df['hE_ref'], '--', label='hE_ref')
plt.xlabel('Tempo [s]')
plt.ylabel('Nível [m]')
plt.title('Níveis dos tanques e referências ao longo do tempo')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Gráficos das concentrações (com referência)

# %%
plt.figure(figsize=(12,6))
plt.plot(df['tempo'], df['CC'], label='CC')
plt.plot(df['tempo'], df['CD'], label='CD')
plt.plot(df['tempo'], df['CE'], label='CE')
plt.plot(df['tempo'], df['CC_ref'], '--', label='CC_ref')
plt.plot(df['tempo'], df['CD_ref'], '--', label='CD_ref')
plt.plot(df['tempo'], df['CE_ref'], '--', label='CE_ref')
plt.xlabel('Tempo [s]')
plt.ylabel('Concentração [kg/m³]')
plt.title('Concentrações e referências ao longo do tempo')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Gráficos dos comandos aplicados

# %%
plt.figure(figsize=(12,6))
plt.plot(df['tempo'], df['uA'], label='uA')
plt.plot(df['tempo'], df['uB'], label='uB')
plt.plot(df['tempo'], df['uC1'], label='uC1')
plt.plot(df['tempo'], df['uC2'], label='uC2')
plt.plot(df['tempo'], df['uC3'], label='uC3')
plt.plot(df['tempo'], df['uD1'], label='uD1')
plt.plot(df['tempo'], df['uD2'], label='uD2')
plt.plot(df['tempo'], df['uD3'], label='uD3')
plt.plot(df['tempo'], df['uE1'], label='uE1')
plt.plot(df['tempo'], df['uE2'], label='uE2')
plt.plot(df['tempo'], df['uE3'], label='uE3')
plt.xlabel('Tempo [s]')
plt.ylabel('Comando')
plt.title('Comandos aplicados ao longo do tempo')
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.grid(True)
plt.show()

# %%
fig, axs = plt.subplots(3, 1, figsize=(14, 10))
fig.dpi = 300

# Níveis dos tanques
axs[0].plot(df['tempo'], df['hA'], label='hA')
axs[0].plot(df['tempo'], df['hB'], label='hB')
axs[0].plot(df['tempo'], df['hC'], label='hC')
axs[0].plot(df['tempo'], df['hD'], label='hD')
axs[0].plot(df['tempo'], df['hE'], label='hE')
axs[0].plot(df['tempo'], df['hC_ref'], '--', label='hC_ref')
axs[0].plot(df['tempo'], df['hD_ref'], '--', label='hD_ref')
axs[0].plot(df['tempo'], df['hE_ref'], '--', label='hE_ref')
axs[0].set_xlabel('Tempo [s]')
axs[0].set_ylabel('Nível [m]')
axs[0].set_title('Níveis dos tanques e referências')
axs[0].legend()
axs[0].grid(True)

# Concentrações
axs[1].plot(df['tempo'], df['CC'], label='CC')
axs[1].plot(df['tempo'], df['CD'], label='CD')
axs[1].plot(df['tempo'], df['CE'], label='CE')
axs[1].plot(df['tempo'], df['CC_ref'], '--', label='CC_ref')
axs[1].plot(df['tempo'], df['CD_ref'], '--', label='CD_ref')
axs[1].plot(df['tempo'], df['CE_ref'], '--', label='CE_ref')
axs[1].set_xlabel('Tempo [s]')
axs[1].set_ylabel('Concentração [kg/m³]')
axs[1].set_title('Concentrações e referências')
axs[1].legend()
axs[1].grid(True)

# Comandos
axs[2].plot(df['tempo'], df['uA'], label='uA')
axs[2].plot(df['tempo'], df['uB'], label='uB')
axs[2].plot(df['tempo'], df['uC1'], label='uC1')
axs[2].plot(df['tempo'], df['uC2'], label='uC2')
axs[2].plot(df['tempo'], df['uC3'], label='uC3')
axs[2].plot(df['tempo'], df['uD1'], label='uD1')
axs[2].plot(df['tempo'], df['uD2'], label='uD2')
axs[2].plot(df['tempo'], df['uD3'], label='uD3')
axs[2].plot(df['tempo'], df['uE1'], label='uE1')
axs[2].plot(df['tempo'], df['uE2'], label='uE2')
axs[2].plot(df['tempo'], df['uE3'], label='uE3')
axs[2].set_xlabel('Tempo [s]')
axs[2].set_ylabel('Comando')
axs[2].set_title('Comandos aplicados')
axs[2].legend(loc='upper right', bbox_to_anchor=(1.15, 1))
axs[2].grid(True)

plt.tight_layout()
plt.show()
